# %%
import os

def tree(dir_path, prefix=""):
    # Get a sorted list of files and directories
    entries = sorted(os.listdir(dir_path))
    entries_count = len(entries)

    for index, entry in enumerate(entries):
        path = os.path.join(dir_path, entry)
        connector = "├── " if index < entries_count - 1 else "└── "

        print(prefix + connector + entry)

        if os.path.isdir(path):
            extension = "│   " if index < entries_count - 1 else "    "
            tree(path, prefix + extension)

if __name__ == "__main__":
    import sys

    # Use current directory or user-provided path
    base_path = "/home/raj/Documents/CODDING/PROJECT/ionia-next/frontend-new/src"
    print(base_path)
    tree(base_path)
# Out:
# /home/raj/Documents/CODDING/PROJECT/ionia-next/frontend-new/src
# ├── app
# │   ├── (admin)
# │   │   ├── analytics
# │   │   │   └── page.tsx
# │   │   ├── layout.tsx
# │   │   ├── page.tsx
# │   │   ├── questions
# │   │   │   ├── add
# │   │   │   │   └── page.tsx
# │   │   │   ├── edit
# │   │   │   │   └── [questionId]
# │   │   │   │       └── page.tsx
# │   │   │   └── page.tsx
# │   │   ├── settings
# │   │   │   └── page.tsx
# │   │   ├── tests
# │   │   │   ├── create
# │   │   │   │   └── page.tsx
# │   │   │   ├── edit
# │   │   │   │   └── [id]
# │   │   │   │       └── page.tsx
# │   │   │   ├── page.tsx
# │   │   │   └── view
# │   │   │       └── [id]
# │   │   │           └── page.tsx
# │   │   ├── users
# │   │   │   └── page.tsx
# │   │   └── utils
# │   │       ├── analytics.ts
# │   │       └── api.ts
# │   ├── (auth)
# │   │   ├── forgot-password
# │   │   │   └── page.tsx
# │   │   ├── login
# │   │   │   ├── layout.tsx
# │   │   │   ├── loading.tsx
# │   │   │   └── page.tsx
# │   │   ├── register
# │   │   │   ├── layout.tsx
# │   │   │   ├── loading.tsx
# │   │   │   └── page.tsx
# │   │   └── reset-password
# │   │       └── page.tsx
# │   ├── (exam)
# │   │   └── [examType]
# │   │       ├── [subject]
# │   │       │   ├── [testId]
# │   │       │   │   ├── page.tsx
# │   │       │   │   └── results
# │   │       │   │       └── page.tsx
# │   │       │   └── page.tsx
# │   │       ├── mock-test
# │   │       │   ├── [paperId]
# │   │       │   │   ├── TestWindowClient.tsx
# │   │       │   │   ├── TestWindowClientWrapper.tsx
# │   │       │   │   ├── analysis
# │   │       │   │   │   ├── AnalysisClientComponent.tsx
# │   │       │   │   │   ├── client.tsx
# │   │       │   │   │   └── page.tsx
# │   │       │   │   ├── client.tsx
# │   │       │   │   ├── instructions
# │   │       │   │   │   └── page.tsx
# │   │       │   │   ├── page.tsx
# │   │       │   │   ├── solution
# │   │       │   │   │   └── page.tsx
# │   │       │   │   └── test
# │   │       │   │       ├── TestWindowClient.tsx
# │   │       │   │       ├── TestWindowClientWrapper.tsx
# │   │       │   │       ├── error.tsx
# │   │       │   │       ├── layout.tsx
# │   │       │   │       ├── not-found.tsx
# │   │       │   │       ├── page.tsx
# │   │       │   │       ├── styles.css
# │   │       │   │       └── template.tsx
# │   │       │   └── page.tsx
# │   │       ├── page.tsx
# │   │       ├── practice
# │   │       │   └── page.tsx
# │   │       └── previous-year-paper
# │   │           ├── [paperId]
# │   │           │   ├── TestWindowClient.tsx
# │   │           │   ├── TestWindowClientWrapper.tsx
# │   │           │   ├── analysis
# │   │           │   │   ├── AnalysisClientComponent.tsx
# │   │           │   │   ├── client.tsx
# │   │           │   │   └── page.tsx
# │   │           │   ├── client.tsx
# │   │           │   ├── instructions
# │   │           │   │   └── page.tsx
# │   │           │   ├── page.tsx
# │   │           │   ├── solution
# │   │           │   │   └── page.tsx
# │   │           │   └── test
# │   │           │       ├── TestWindowClient.tsx
# │   │           │       ├── TestWindowClientWrapper.tsx
# │   │           │       ├── error.tsx
# │   │           │       ├── layout.tsx
# │   │           │       ├── not-found.tsx
# │   │           │       ├── page.tsx
# │   │           │       ├── styles.css
# │   │           │       └── template.tsx
# │   │           └── page.tsx
# │   ├── (marketing)
# │   │   └── page.tsx
# │   ├── dashboard
# │   │   ├── analytics
# │   │   │   └── page.tsx
# │   │   ├── layout.tsx
# │   │   ├── loading.tsx
# │   │   ├── page.tsx
# │   │   └── tests
# │   │       ├── [attemptId]
# │   │       │   ├── AnalysisClientComponent.tsx
# │   │       │   ├── client.tsx
# │   │       │   ├── page.tsx
# │   │       │   └── solution
# │   │       │       └── page.tsx
# │   │       └── page.tsx
# │   ├── layout.tsx
# │   ├── page.tsx
# │   └── results
# │       └── page.tsx
# ├── features
# │   ├── admin
# │   │   ├── api
# │   │   ├── components
# │   │   │   ├── Sidebar.tsx
# │   │   │   └── tests
# │   │   │       ├── MultiSelect.tsx
# │   │   │       ├── TestCreationStepper.tsx
# │   │   │       ├── TestDetailsForm.tsx
# │   │   │       ├── questions
# │   │   │       │   ├── QuestionCard.tsx
# │   │   │       │   ├── QuestionFilter.tsx
# │   │   │       │   ├── QuestionSelection.tsx
# │   │   │       │   ├── QuestionsPagination.tsx
# │   │   │       │   ├── SelectedQuestionsMetrics.tsx
# │   │   │       │   └── types.ts
# │   │   │       └── types.ts
# │   │   ├── hooks
# │   │   │   └── useUserManagement.ts
# │   │   ├── index.ts
# │   │   ├── services
# │   │   ├── store
# │   │   ├── types.ts
# │   │   └── utils
# │   ├── analysis
# │   │   ├── api
# │   │   │   └── api.ts
# │   │   ├── components
# │   │   │   └── AnalysisWindow
# │   │   │       ├── AttemptsAnalysis.tsx
# │   │   │       ├── BehavioralAnalysis.tsx
# │   │   │       ├── ErrorAnalysis.tsx
# │   │   │       ├── Header.tsx
# │   │   │       ├── PerformanceAnalysis.tsx
# │   │   │       ├── QualityTimeSpent.tsx
# │   │   │       ├── QuestionAnalysis.tsx
# │   │   │       ├── StrategyAnalysis.tsx
# │   │   │       ├── SubjectAnalysis.tsx
# │   │   │       ├── SubjectWiseTime.tsx
# │   │   │       ├── Summary.tsx
# │   │   │       ├── Tabs.tsx
# │   │   │       ├── TimeAnalysis.tsx
# │   │   │       └── index.tsx
# │   │   ├── hooks
# │   │   │   └── useAnalysisData.tsx
# │   │   ├── index.ts
# │   │   ├── services
# │   │   ├── store
# │   │   │   └── analysisStore.ts
# │   │   ├── types.ts
# │   │   └── utils
# │   ├── auth
# │   │   ├── api
# │   │   │   └── authApi.ts
# │   │   ├── components
# │   │   │   ├── AuthComponents.tsx
# │   │   │   ├── ForgotPasswordForm.tsx
# │   │   │   ├── LoginForm.tsx
# │   │   │   ├── ProtectedRoute.tsx
# │   │   │   ├── RegisterForm.tsx
# │   │   │   ├── RoleGuard.tsx
# │   │   │   └── SessionSync.tsx
# │   │   ├── hooks
# │   │   │   └── useAuth.ts
# │   │   ├── index.ts
# │   │   ├── services
# │   │   │   └── authService.ts
# │   │   ├── store
# │   │   │   └── authStore.ts
# │   │   ├── types.ts
# │   │   └── utils
# │   │       └── authUtils.ts
# │   ├── dashboard
# │   │   ├── api
# │   │   ├── components
# │   │   │   ├── PerformanceChart.tsx
# │   │   │   ├── RecentTests.tsx
# │   │   │   ├── Sidebar.tsx
# │   │   │   ├── StatsCard.tsx
# │   │   │   ├── SubjectPerformance.tsx
# │   │   │   ├── TestHistory.tsx
# │   │   │   ├── UpcomingTests.tsx
# │   │   │   ├── UserProfile.tsx
# │   │   │   └── card.tsx
# │   │   ├── hooks
# │   │   ├── index.ts
# │   │   ├── services
# │   │   ├── store
# │   │   ├── types.ts
# │   │   └── utils
# │   ├── exam
# │   │   ├── api
# │   │   ├── components
# │   │   ├── hooks
# │   │   ├── index.ts
# │   │   ├── services
# │   │   ├── store
# │   │   ├── types.ts
# │   │   └── utils
# │   ├── practice
# │   │   ├── api
# │   │   ├── components
# │   │   ├── hooks
# │   │   ├── index.ts
# │   │   ├── services
# │   │   ├── store
# │   │   ├── types.ts
# │   │   └── utils
# │   ├── profile
# │   │   ├── api
# │   │   ├── components
# │   │   ├── hooks
# │   │   ├── index.ts
# │   │   ├── services
# │   │   ├── store
# │   │   ├── types.ts
# │   │   └── utils
# │   ├── questions
# │   │   ├── api
# │   │   │   └── questionsApi.ts
# │   │   ├── components
# │   │   │   ├── PreviewQuestion.tsx
# │   │   │   ├── QuestionPaletteIcons
# │   │   │   │   └── index.tsx
# │   │   │   ├── edit
# │   │   │   │   ├── QuestionEditForm.tsx
# │   │   │   │   ├── QuestionPreview.tsx
# │   │   │   │   ├── QuestionStatistics.tsx
# │   │   │   │   └── RevisionHistory.tsx
# │   │   │   ├── form
# │   │   │   │   ├── CurriculumDisplay.tsx
# │   │   │   │   ├── FormNavigation.tsx
# │   │   │   │   ├── FormStepper.tsx
# │   │   │   │   ├── QuestionForm.tsx
# │   │   │   │   ├── SectionSelector.tsx
# │   │   │   │   ├── ViewAllChaptersModal.tsx
# │   │   │   │   ├── preview
# │   │   │   │   │   ├── PreviewModal.tsx
# │   │   │   │   │   └── QuestionPreview.tsx
# │   │   │   │   └── steps
# │   │   │   │       ├── DetailsClassification.tsx
# │   │   │   │       ├── QuestionContent.tsx
# │   │   │   │       ├── SolutionHints.tsx
# │   │   │   │       └── TagsTopics.tsx
# │   │   │   ├── inputs
# │   │   │   │   ├── FileUpload.tsx
# │   │   │   │   └── ImagePreview.tsx
# │   │   │   └── utils
# │   │   │       ├── constants.ts
# │   │   │       ├── types.ts
# │   │   │       ├── useQuestionForm.ts
# │   │   │       └── validation.ts
# │   │   ├── hooks
# │   │   ├── index.ts
# │   │   ├── services
# │   │   ├── store
# │   │   ├── types.ts
# │   │   └── utils
# │   ├── solution
# │   │   ├── api
# │   │   ├── components
# │   │   │   ├── NavigationBar
# │   │   │   │   └── index.tsx
# │   │   │   ├── QuestionNavigator
# │   │   │   │   └── index.tsx
# │   │   │   ├── SolutionCard
# │   │   │   │   └── index.tsx
# │   │   │   ├── Summary
# │   │   │   │   └── index.tsx
# │   │   │   └── index.tsx
# │   │   ├── hooks
# │   │   ├── index.ts
# │   │   ├── services
# │   │   ├── store
# │   │   ├── types.ts
# │   │   └── utils
# │   │       └── util.tsx
# │   └── tests
# │       ├── api
# │       │   └── testsApi.ts
# │       ├── components
# │       │   └── TestWindow
# │       │       ├── Controls
# │       │       │   ├── ActionButtons.tsx
# │       │       │   └── LanguageSelector.tsx
# │       │       ├── Header
# │       │       │   ├── CandidateInfo.tsx
# │       │       │   ├── Timer.tsx
# │       │       │   └── index.tsx
# │       │       ├── Navigation
# │       │       │   └── QuestionGrid.tsx
# │       │       ├── QuestionPanel.tsx
# │       │       ├── StatusPanel
# │       │       │   └── QuestionStatus.tsx
# │       │       └── index.tsx
# │       ├── hooks
# │       │   ├── useQuestionNavigation.ts
# │       │   ├── useQuestionStatus.ts
# │       │   ├── useTestProgress.ts
# │       │   ├── useTestSession.ts
# │       │   └── useTimer.ts
# │       ├── index.ts
# │       ├── services
# │       ├── store
# │       │   └── testStore.ts
# │       ├── types.ts
# │       └── utils
# ├── lib
# │   ├── api
# │   │   └── api.ts
# │   ├── interceptors
# │   │   └── authInterceptor.ts
# │   └── validation.ts
# ├── providers
# │   └── AuthProvider.tsx
# ├── shared
# │   ├── components
# │   │   ├── ErrorBoundary.tsx
# │   │   ├── common
# │   │   │   ├── Button.tsx
# │   │   │   ├── CookieConsent.tsx
# │   │   │   ├── Footer.tsx
# │   │   │   ├── Input.tsx
# │   │   │   ├── Layout.tsx
# │   │   │   ├── Loading.tsx
# │   │   │   ├── Modal.tsx
# │   │   │   ├── Navbar.tsx
# │   │   │   └── Notifications.tsx
# │   │   └── ui
# │   │       ├── alert-dialog.tsx
# │   │       ├── badge.tsx
# │   │       ├── button.tsx
# │   │       ├── card.tsx
# │   │       ├── checkbox.tsx
# │   │       ├── dialog.tsx
# │   │       ├── dropdown-menu.tsx
# │   │       ├── input.tsx
# │   │       ├── label.tsx
# │   │       ├── scroll-area.tsx
# │   │       ├── select.tsx
# │   │       ├── skeleton.tsx
# │   │       ├── switch.tsx
# │   │       ├── table.tsx
# │   │       ├── tabs.tsx
# │   │       └── textarea.tsx
# │   ├── hooks
# │   │   ├── useMediaQuery.ts
# │   │   ├── useQuestionCleanup.ts
# │   │   └── useQuestionDraft.ts
# │   ├── icons
# │   ├── layout
# │   ├── styles
# │   └── utils
# │       ├── format.ts
# │       └── time.ts
# ├── stores
# │   ├── cacheStore.ts
# │   ├── questionStore.ts
# │   ├── storeInit.ts
# │   ├── timeTrackingStore.ts
# │   └── uiStore.ts
# ├── styles
# │   └── globals.css
# ├── types
# │   ├── form.ts
# │   ├── global.d.ts
# │   ├── question.ts
# │   ├── test.ts
# │   ├── testWindow.ts
# │   ├── user.d.ts
# │   └── user.ts
# └── utils
#     ├── authUtils.ts
#     ├── environmentCheck.ts
#     └── permissions.ts
