# %%
import os

def tree(dir_path, prefix=""):
    # Get a sorted list of files and directories
    entries = sorted(os.listdir(dir_path))
    entries_count = len(entries)

    for index, entry in enumerate(entries):
        path = os.path.join(dir_path, entry)
        connector = "├── " if index < entries_count - 1 else "└── "

        print(prefix + connector + entry)

        if os.path.isdir(path):
            extension = "│   " if index < entries_count - 1 else "    "
            tree(path, prefix + extension)

if __name__ == "__main__":
    import sys

    # Use current directory or user-provided path
    base_path = "/home/raj/Documents/CODDING/PROJECT/ionia-next/frontend/src"
    print(base_path)
    tree(base_path)
# Out:
# /home/raj/Documents/CODDING/PROJECT/ionia-next/frontend/src
# ├── app
# │   ├── admin
# │   │   ├── analytics
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   ├── layout.tsx
# │   │   ├── layout.tsx.backup
# │   │   ├── page.tsx
# │   │   ├── page.tsx.backup
# │   │   ├── questions
# │   │   │   ├── add
# │   │   │   │   ├── page.tsx
# │   │   │   │   └── page.tsx.backup
# │   │   │   ├── edit
# │   │   │   │   └── [questionId]
# │   │   │   │       ├── page.tsx
# │   │   │   │       └── page.tsx.backup
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   ├── settings
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   ├── tests
# │   │   │   ├── create
# │   │   │   │   ├── page.tsx
# │   │   │   │   └── page.tsx.backup
# │   │   │   ├── edit
# │   │   │   │   └── [id]
# │   │   │   │       ├── page.tsx
# │   │   │   │       └── page.tsx.backup
# │   │   │   ├── page.tsx
# │   │   │   ├── page.tsx.backup
# │   │   │   └── view
# │   │   │       └── [id]
# │   │   │           ├── page.tsx
# │   │   │           └── page.tsx.backup
# │   │   ├── users
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   └── utils
# │   │       ├── analytics.ts
# │   │       ├── analytics.ts.backup
# │   │       ├── api.ts
# │   │       └── api.ts.backup
# │   ├── auth
# │   │   ├── forgot-password
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   ├── login
# │   │   │   ├── layout.tsx
# │   │   │   ├── layout.tsx.backup
# │   │   │   ├── loading.tsx
# │   │   │   ├── loading.tsx.backup
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   ├── register
# │   │   │   ├── layout.tsx
# │   │   │   ├── layout.tsx.backup
# │   │   │   ├── loading.tsx
# │   │   │   ├── loading.tsx.backup
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   └── reset-password
# │   │       ├── page.tsx
# │   │       └── page.tsx.backup
# │   ├── custom-test
# │   │   ├── create
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   ├── page.tsx
# │   │   └── page.tsx.backup
# │   ├── dashboard
# │   │   ├── analytics
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   ├── layout.tsx
# │   │   ├── layout.tsx.backup
# │   │   ├── loading.tsx
# │   │   ├── loading.tsx.backup
# │   │   ├── page.tsx
# │   │   ├── page.tsx.backup
# │   │   └── tests
# │   │       ├── [attemptId]
# │   │       │   ├── AnalysisClientComponent.tsx
# │   │       │   ├── AnalysisClientComponent.tsx.backup
# │   │       │   ├── client.tsx
# │   │       │   ├── client.tsx.backup
# │   │       │   ├── page.tsx
# │   │       │   ├── page.tsx.backup
# │   │       │   └── solution
# │   │       │       ├── page.tsx
# │   │       │       └── page.tsx.backup
# │   │       ├── page.tsx
# │   │       └── page.tsx.backup
# │   ├── exam
# │   │   └── [examType]
# │   │       ├── [subject]
# │   │       │   ├── [testId]
# │   │       │   │   ├── page.tsx
# │   │       │   │   ├── page.tsx.backup
# │   │       │   │   └── results
# │   │       │   │       ├── page.tsx
# │   │       │   │       └── page.tsx.backup
# │   │       │   ├── page.tsx
# │   │       │   └── page.tsx.backup
# │   │       ├── mock-test
# │   │       │   ├── [paperId]
# │   │       │   │   ├── TestWindowClient.tsx
# │   │       │   │   ├── TestWindowClient.tsx.backup
# │   │       │   │   ├── TestWindowClientWrapper.tsx
# │   │       │   │   ├── TestWindowClientWrapper.tsx.backup
# │   │       │   │   ├── analysis
# │   │       │   │   │   ├── AnalysisClientComponent.tsx
# │   │       │   │   │   ├── AnalysisClientComponent.tsx.backup
# │   │       │   │   │   ├── client.tsx
# │   │       │   │   │   ├── client.tsx.backup
# │   │       │   │   │   ├── page.tsx
# │   │       │   │   │   └── page.tsx.backup
# │   │       │   │   ├── client.tsx
# │   │       │   │   ├── client.tsx.backup
# │   │       │   │   ├── instructions
# │   │       │   │   │   ├── page.tsx
# │   │       │   │   │   └── page.tsx.backup
# │   │       │   │   ├── page.tsx
# │   │       │   │   ├── page.tsx.backup
# │   │       │   │   ├── solution
# │   │       │   │   │   ├── page.tsx
# │   │       │   │   │   └── page.tsx.backup
# │   │       │   │   └── test
# │   │       │   │       ├── TestWindowClient.tsx
# │   │       │   │       ├── TestWindowClient.tsx.backup
# │   │       │   │       ├── TestWindowClientWrapper.tsx
# │   │       │   │       ├── TestWindowClientWrapper.tsx.backup
# │   │       │   │       ├── error.tsx
# │   │       │   │       ├── error.tsx.backup
# │   │       │   │       ├── layout.tsx
# │   │       │   │       ├── layout.tsx.backup
# │   │       │   │       ├── not-found.tsx
# │   │       │   │       ├── not-found.tsx.backup
# │   │       │   │       ├── page.tsx
# │   │       │   │       ├── page.tsx.backup
# │   │       │   │       ├── styles.css
# │   │       │   │       ├── template.tsx
# │   │       │   │       └── template.tsx.backup
# │   │       │   ├── page.tsx
# │   │       │   └── page.tsx.backup
# │   │       ├── page.tsx
# │   │       ├── page.tsx.backup
# │   │       ├── practice
# │   │       │   ├── page.tsx
# │   │       │   └── page.tsx.backup
# │   │       └── previous-year-paper
# │   │           ├── [paperId]
# │   │           │   ├── TestWindowClient.tsx
# │   │           │   ├── TestWindowClient.tsx.backup
# │   │           │   ├── TestWindowClientWrapper.tsx
# │   │           │   ├── TestWindowClientWrapper.tsx.backup
# │   │           │   ├── analysis
# │   │           │   │   ├── AnalysisClientComponent.tsx
# │   │           │   │   ├── AnalysisClientComponent.tsx.backup
# │   │           │   │   ├── client.tsx
# │   │           │   │   ├── client.tsx.backup
# │   │           │   │   ├── page.tsx
# │   │           │   │   └── page.tsx.backup
# │   │           │   ├── client.tsx
# │   │           │   ├── client.tsx.backup
# │   │           │   ├── instructions
# │   │           │   │   ├── page.tsx
# │   │           │   │   └── page.tsx.backup
# │   │           │   ├── page.tsx
# │   │           │   ├── page.tsx.backup
# │   │           │   ├── solution
# │   │           │   │   ├── page.tsx
# │   │           │   │   └── page.tsx.backup
# │   │           │   └── test
# │   │           │       ├── TestWindowClient.tsx
# │   │           │       ├── TestWindowClient.tsx.backup
# │   │           │       ├── TestWindowClientWrapper.tsx
# │   │           │       ├── TestWindowClientWrapper.tsx.backup
# │   │           │       ├── error.tsx
# │   │           │       ├── error.tsx.backup
# │   │           │       ├── layout.tsx
# │   │           │       ├── layout.tsx.backup
# │   │           │       ├── not-found.tsx
# │   │           │       ├── not-found.tsx.backup
# │   │           │       ├── page.tsx
# │   │           │       ├── page.tsx.backup
# │   │           │       ├── styles.css
# │   │           │       ├── template.tsx
# │   │           │       └── template.tsx.backup
# │   │           ├── page.tsx
# │   │           └── page.tsx.backup
# │   ├── layout.tsx
# │   ├── layout.tsx.backup
# │   ├── page.tsx
# │   ├── page.tsx.backup
# │   ├── practices
# │   │   ├── [subjectId]
# │   │   │   ├── [chapterId]
# │   │   │   │   ├── page.tsx
# │   │   │   │   └── page.tsx.backup
# │   │   │   ├── page.tsx
# │   │   │   └── page.tsx.backup
# │   │   ├── page.tsx
# │   │   └── page.tsx.backup
# │   ├── profile
# │   │   ├── page.tsx
# │   │   ├── page.tsx.backup
# │   │   └── settings
# │   │       ├── page.tsx
# │   │       └── page.tsx.backup
# │   └── results
# │       ├── page.tsx
# │       └── page.tsx.backup
# ├── components
# │   ├── ErrorBoundary.tsx
# │   ├── ErrorBoundary.tsx.backup
# │   ├── QuestionPaletteIcons
# │   │   ├── index.tsx
# │   │   └── index.tsx.backup
# │   ├── admin
# │   │   ├── Sidebar.tsx
# │   │   ├── Sidebar.tsx.backup
# │   │   └── tests
# │   │       ├── MultiSelect.tsx
# │   │       ├── MultiSelect.tsx.backup
# │   │       ├── TestCreationStepper.tsx
# │   │       ├── TestCreationStepper.tsx.backup
# │   │       ├── TestDetailsForm.tsx
# │   │       ├── TestDetailsForm.tsx.backup
# │   │       ├── questions
# │   │       │   ├── QuestionCard.tsx
# │   │       │   ├── QuestionCard.tsx.backup
# │   │       │   ├── QuestionFilter.tsx
# │   │       │   ├── QuestionFilter.tsx.backup
# │   │       │   ├── QuestionSelection.tsx
# │   │       │   ├── QuestionSelection.tsx.backup
# │   │       │   ├── QuestionsPagination.tsx
# │   │       │   ├── QuestionsPagination.tsx.backup
# │   │       │   ├── SelectedQuestionsMetrics.tsx
# │   │       │   ├── SelectedQuestionsMetrics.tsx.backup
# │   │       │   ├── types.ts
# │   │       │   └── types.ts.backup
# │   │       ├── types.ts
# │   │       └── types.ts.backup
# │   ├── analysis
# │   │   ├── AnalysisWindow
# │   │   │   ├── AttemptsAnalysis.tsx
# │   │   │   ├── AttemptsAnalysis.tsx.backup
# │   │   │   ├── BehavioralAnalysis.tsx
# │   │   │   ├── BehavioralAnalysis.tsx.backup
# │   │   │   ├── ErrorAnalysis.tsx
# │   │   │   ├── ErrorAnalysis.tsx.backup
# │   │   │   ├── Header.tsx
# │   │   │   ├── Header.tsx.backup
# │   │   │   ├── PerformanceAnalysis.tsx
# │   │   │   ├── PerformanceAnalysis.tsx.backup
# │   │   │   ├── QualityTimeSpent.tsx
# │   │   │   ├── QualityTimeSpent.tsx.backup
# │   │   │   ├── QuestionAnalysis.tsx
# │   │   │   ├── QuestionAnalysis.tsx.backup
# │   │   │   ├── StrategyAnalysis.tsx
# │   │   │   ├── StrategyAnalysis.tsx.backup
# │   │   │   ├── SubjectAnalysis.tsx
# │   │   │   ├── SubjectAnalysis.tsx.backup
# │   │   │   ├── SubjectWiseTime.tsx
# │   │   │   ├── SubjectWiseTime.tsx.backup
# │   │   │   ├── Summary.tsx
# │   │   │   ├── Summary.tsx.backup
# │   │   │   ├── Tabs.tsx
# │   │   │   ├── Tabs.tsx.backup
# │   │   │   ├── TimeAnalysis.tsx
# │   │   │   ├── TimeAnalysis.tsx.backup
# │   │   │   ├── index.tsx
# │   │   │   └── index.tsx.backup
# │   │   ├── api.ts
# │   │   ├── api.ts.backup
# │   │   ├── hooks
# │   │   │   ├── useAnalysisData.tsx
# │   │   │   └── useAnalysisData.tsx.backup
# │   │   ├── index.ts
# │   │   └── index.ts.backup
# │   ├── auth
# │   │   ├── ForgotPasswordForm.tsx
# │   │   ├── ForgotPasswordForm.tsx.backup
# │   │   ├── LoginForm.tsx
# │   │   ├── LoginForm.tsx.backup
# │   │   ├── ProtectedRoute.tsx
# │   │   ├── ProtectedRoute.tsx.backup
# │   │   ├── RegisterForm.tsx
# │   │   ├── RegisterForm.tsx.backup
# │   │   ├── RoleGuard.tsx
# │   │   ├── RoleGuard.tsx.backup
# │   │   ├── SessionSync.tsx
# │   │   └── SessionSync.tsx.backup
# │   ├── common
# │   │   ├── Button.tsx
# │   │   ├── Button.tsx.backup
# │   │   ├── CookieConsent.tsx
# │   │   ├── CookieConsent.tsx.backup
# │   │   ├── ErrorBoundary.tsx
# │   │   ├── ErrorBoundary.tsx.backup
# │   │   ├── Footer.tsx
# │   │   ├── Footer.tsx.backup
# │   │   ├── Input.tsx
# │   │   ├── Input.tsx.backup
# │   │   ├── Layout.tsx
# │   │   ├── Layout.tsx.backup
# │   │   ├── Loading.tsx
# │   │   ├── Loading.tsx.backup
# │   │   ├── Modal.tsx
# │   │   ├── Modal.tsx.backup
# │   │   ├── Navbar.tsx
# │   │   ├── Navbar.tsx.backup
# │   │   ├── Notifications.tsx
# │   │   └── Notifications.tsx.backup
# │   ├── dashboard
# │   │   ├── PerformanceChart.tsx
# │   │   ├── PerformanceChart.tsx.backup
# │   │   ├── RecentTests.tsx
# │   │   ├── RecentTests.tsx.backup
# │   │   ├── Sidebar.tsx
# │   │   ├── Sidebar.tsx.backup
# │   │   ├── StatsCard.tsx
# │   │   ├── StatsCard.tsx.backup
# │   │   ├── SubjectPerformance.tsx
# │   │   ├── SubjectPerformance.tsx.backup
# │   │   ├── TestHistory.tsx
# │   │   ├── TestHistory.tsx.backup
# │   │   ├── UpcomingTests.tsx
# │   │   ├── UpcomingTests.tsx.backup
# │   │   ├── UserProfile.tsx
# │   │   ├── UserProfile.tsx.backup
# │   │   ├── card.tsx
# │   │   └── card.tsx.backup
# │   ├── practice
# │   │   ├── AnswerSummary.tsx
# │   │   ├── AnswerSummary.tsx.backup
# │   │   ├── ChapterList.tsx
# │   │   ├── ChapterList.tsx.backup
# │   │   ├── PracticeQuestion.tsx
# │   │   ├── PracticeQuestion.tsx.backup
# │   │   ├── ResultPage.tsx
# │   │   ├── ResultPage.tsx.backup
# │   │   ├── TopicCard.tsx
# │   │   └── TopicCard.tsx.backup
# │   ├── questions
# │   │   ├── PreviewQuestion.tsx
# │   │   ├── PreviewQuestion.tsx.backup
# │   │   ├── edit
# │   │   │   ├── QuestionEditForm.tsx
# │   │   │   ├── QuestionEditForm.tsx.backup
# │   │   │   ├── QuestionPreview.tsx
# │   │   │   ├── QuestionPreview.tsx.backup
# │   │   │   ├── QuestionStatistics.tsx
# │   │   │   ├── QuestionStatistics.tsx.backup
# │   │   │   ├── RevisionHistory.tsx
# │   │   │   └── RevisionHistory.tsx.backup
# │   │   ├── form
# │   │   │   ├── CurriculumDisplay.tsx
# │   │   │   ├── CurriculumDisplay.tsx.backup
# │   │   │   ├── FormNavigation.tsx
# │   │   │   ├── FormNavigation.tsx.backup
# │   │   │   ├── FormStepper.tsx
# │   │   │   ├── FormStepper.tsx.backup
# │   │   │   ├── QuestionForm.tsx
# │   │   │   ├── QuestionForm.tsx.backup
# │   │   │   ├── SectionSelector.tsx
# │   │   │   ├── SectionSelector.tsx.backup
# │   │   │   ├── ViewAllChaptersModal.tsx
# │   │   │   ├── ViewAllChaptersModal.tsx.backup
# │   │   │   ├── preview
# │   │   │   │   ├── PreviewModal.tsx
# │   │   │   │   ├── PreviewModal.tsx.backup
# │   │   │   │   ├── QuestionPreview.tsx
# │   │   │   │   └── QuestionPreview.tsx.backup
# │   │   │   ├── steps
# │   │   │   │   ├── DetailsClassification.tsx
# │   │   │   │   ├── DetailsClassification.tsx.backup
# │   │   │   │   ├── QuestionContent.tsx
# │   │   │   │   ├── QuestionContent.tsx.backup
# │   │   │   │   ├── SolutionHints.tsx
# │   │   │   │   ├── SolutionHints.tsx.backup
# │   │   │   │   ├── TagsTopics.tsx
# │   │   │   │   └── TagsTopics.tsx.backup
# │   │   │   └── temp.txt
# │   │   ├── inputs
# │   │   │   ├── FileUpload.tsx
# │   │   │   ├── FileUpload.tsx.backup
# │   │   │   ├── ImagePreview.tsx
# │   │   │   └── ImagePreview.tsx.backup
# │   │   └── utils
# │   │       ├── constants.ts
# │   │       ├── constants.ts.backup
# │   │       ├── types.ts
# │   │       ├── types.ts.backup
# │   │       ├── useQuestionForm.ts
# │   │       ├── useQuestionForm.ts.backup
# │   │       ├── validation.ts
# │   │       └── validation.ts.backup
# │   ├── solution
# │   │   ├── NavigationBar
# │   │   │   ├── index.tsx
# │   │   │   └── index.tsx.backup
# │   │   ├── QuestionNavigator
# │   │   │   ├── index.tsx
# │   │   │   └── index.tsx.backup
# │   │   ├── SolutionCard
# │   │   │   ├── index.tsx
# │   │   │   └── index.tsx.backup
# │   │   ├── Summary
# │   │   │   ├── index.tsx
# │   │   │   └── index.tsx.backup
# │   │   ├── index.tsx
# │   │   ├── index.tsx.backup
# │   │   ├── util.tsx
# │   │   └── util.tsx.backup
# │   ├── test
# │   │   ├── TestWindow
# │   │   │   ├── Controls
# │   │   │   │   ├── ActionButtons.tsx
# │   │   │   │   ├── ActionButtons.tsx.backup
# │   │   │   │   ├── LanguageSelector.tsx
# │   │   │   │   └── LanguageSelector.tsx.backup
# │   │   │   ├── Header
# │   │   │   │   ├── CandidateInfo.tsx
# │   │   │   │   ├── CandidateInfo.tsx.backup
# │   │   │   │   ├── Timer.tsx
# │   │   │   │   ├── Timer.tsx.backup
# │   │   │   │   ├── index.tsx
# │   │   │   │   └── index.tsx.backup
# │   │   │   ├── Navigation
# │   │   │   │   ├── QuestionGrid.tsx
# │   │   │   │   └── QuestionGrid.tsx.backup
# │   │   │   ├── QuestionPanel.tsx
# │   │   │   ├── QuestionPanel.tsx.backup
# │   │   │   ├── StatusPanel
# │   │   │   │   ├── QuestionStatus.tsx
# │   │   │   │   └── QuestionStatus.tsx.backup
# │   │   │   ├── index.tsx
# │   │   │   └── index.tsx.backup
# │   │   └── hey
# │   └── ui
# │       ├── alert-dialog.tsx
# │       ├── alert-dialog.tsx.backup
# │       ├── badge.tsx
# │       ├── badge.tsx.backup
# │       ├── button.tsx
# │       ├── button.tsx.backup
# │       ├── card.tsx
# │       ├── card.tsx.backup
# │       ├── checkbox.tsx
# │       ├── checkbox.tsx.backup
# │       ├── dialog.tsx
# │       ├── dialog.tsx.backup
# │       ├── dropdown-menu.tsx
# │       ├── dropdown-menu.tsx.backup
# │       ├── input.tsx
# │       ├── input.tsx.backup
# │       ├── label.tsx
# │       ├── label.tsx.backup
# │       ├── scroll-area.tsx
# │       ├── scroll-area.tsx.backup
# │       ├── select.tsx
# │       ├── select.tsx.backup
# │       ├── skeleton.tsx
# │       ├── skeleton.tsx.backup
# │       ├── switch.tsx
# │       ├── switch.tsx.backup
# │       ├── table.tsx
# │       ├── table.tsx.backup
# │       ├── tabs.tsx
# │       ├── tabs.tsx.backup
# │       ├── textarea.tsx
# │       └── textarea.tsx.backup
# ├── context
# │   ├── AnalysisContext.tsx
# │   └── AnalysisContext.tsx.backup
# ├── hooks
# │   ├── useMediaQuery.ts
# │   ├── useMediaQuery.ts.backup
# │   ├── useQuestionCleanup.ts
# │   ├── useQuestionCleanup.ts.backup
# │   ├── useQuestionDraft.ts
# │   └── useQuestionDraft.ts.backup
# ├── lib
# │   ├── api
# │   │   ├── auth.ts
# │   │   ├── auth.ts.backup
# │   │   ├── questions.ts
# │   │   ├── questions.ts.backup
# │   │   ├── tests.ts
# │   │   ├── tests.ts.backup
# │   │   ├── user.ts
# │   │   └── user.ts.backup
# │   ├── api.ts
# │   ├── api.ts.backup
# │   ├── constants.ts
# │   ├── constants.ts.backup
# │   ├── hooks
# │   │   ├── useAuth.ts
# │   │   ├── useAuth.ts.backup
# │   │   ├── useQuestionNavigation.ts
# │   │   ├── useQuestionNavigation.ts.backup
# │   │   ├── useQuestionStatus.ts
# │   │   ├── useQuestionStatus.ts.backup
# │   │   ├── useTestProgress.ts
# │   │   ├── useTestProgress.ts.backup
# │   │   ├── useTestSession.ts
# │   │   ├── useTestSession.ts.backup
# │   │   ├── useTimer.ts
# │   │   ├── useTimer.ts.backup
# │   │   ├── useUserManagement.ts
# │   │   └── useUserManagement.ts.backup
# │   ├── performance.ts
# │   ├── performance.ts.backup
# │   ├── utils
# │   │   ├── format.ts
# │   │   ├── format.ts.backup
# │   │   ├── time.ts
# │   │   ├── time.ts.backup
# │   │   ├── validation.ts
# │   │   └── validation.ts.backup
# │   ├── utils.ts
# │   ├── utils.ts.backup
# │   ├── validation.ts
# │   └── validation.ts.backup
# ├── middleware.ts
# ├── middleware.ts.backup
# ├── providers
# │   ├── AuthProvider.tsx
# │   └── AuthProvider.tsx.backup
# ├── stores
# │   ├── analysisStore.ts
# │   ├── analysisStore.ts.backup
# │   ├── authStore.ts
# │   ├── authStore.ts.backup
# │   ├── cacheStore.ts
# │   ├── cacheStore.ts.backup
# │   ├── index.ts
# │   ├── index.ts.backup
# │   ├── questionStore.ts
# │   ├── questionStore.ts.backup
# │   ├── storeInit.ts
# │   ├── storeInit.ts.backup
# │   ├── testStore.ts
# │   ├── testStore.ts.backup
# │   ├── timeTrackingStore.ts
# │   ├── timeTrackingStore.ts.backup
# │   ├── uiStore.ts
# │   └── uiStore.ts.backup
# ├── styles
# │   └── globals.css
# ├── types
# │   ├── analysis.ts
# │   ├── analysis.ts.backup
# │   ├── form.ts
# │   ├── form.ts.backup
# │   ├── global.d.ts
# │   ├── global.d.ts.backup
# │   ├── question.ts
# │   ├── question.ts.backup
# │   ├── test.ts
# │   ├── test.ts.backup
# │   ├── testWindow.ts
# │   ├── testWindow.ts.backup
# │   ├── user.d.ts
# │   ├── user.d.ts.backup
# │   ├── user.ts
# │   └── user.ts.backup
# └── utils
#     ├── environmentCheck.ts
#     ├── environmentCheck.ts.backup
#     ├── permissions.ts
#     └── permissions.ts.backup
